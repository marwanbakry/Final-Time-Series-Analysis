# %% [markdown]
# <a href="https://colab.research.google.com/github/RShakran/Machine-Learning-Project/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Readin The Dataset**

# %%
df = pd.read_csv('Amazon stock 1999 to 2022.csv')
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0       1/4/1999   2.730729   2.966667   2.665625   2.957813   2.957813
# 1       1/5/1999   2.739063   3.243750   2.662500   3.112500   3.112500
# 2       1/6/1999   3.409375   3.509375   3.350000   3.450000   3.450000
# 3       1/7/1999   3.428125   4.006250   3.325000   3.971875   3.971875
# 4       1/8/1999   4.606250   4.978125   3.800000   4.006250   4.006250
# ...          ...        ...        ...        ...        ...        ...
# 6034  12/23/2022  83.250000  85.779999  82.930000  85.250000  85.250000
# 6035  12/27/2022  84.970001  85.349998  83.000000  83.040001  83.040001
# 6036  12/28/2022  82.800003  83.480003  81.690002  81.820000  81.820000
# 6037  12/29/2022  82.870003  84.550003  82.550003  84.180000  84.180000
# 6038  12/30/2022  83.120003  84.050003  82.470001  84.000000  84.000000
#
#           Volume
# 0      785844000
# 1     1257464000
# 2      723532000
# 3      945492000
# ...

# %%
df.head()
# Out:
#        Date      Open      High       Low     Close  Adj Close      Volume
# 0  1/4/1999  2.730729  2.966667  2.665625  2.957813   2.957813   785844000
# 1  1/5/1999  2.739063  3.243750  2.662500  3.112500   3.112500  1257464000
# 2  1/6/1999  3.409375  3.509375  3.350000  3.450000   3.450000   723532000
# 3  1/7/1999  3.428125  4.006250  3.325000  3.971875   3.971875   945492000
# 4  1/8/1999  4.606250  4.978125  3.800000  4.006250   4.006250  1333244000

# %%
df.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 6034  12/23/2022  83.250000  85.779999  82.930000  85.250000  85.250000
# 6035  12/27/2022  84.970001  85.349998  83.000000  83.040001  83.040001
# 6036  12/28/2022  82.800003  83.480003  81.690002  81.820000  81.820000
# 6037  12/29/2022  82.870003  84.550003  82.550003  84.180000  84.180000
# 6038  12/30/2022  83.120003  84.050003  82.470001  84.000000  84.000000
#
#         Volume
# 6034  57433700
# 6035  57284000
# 6036  58228600
# 6037  54995900
# 6038  62401200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6039 entries, 0 to 6038
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6039 non-null   object
#  1   Open       6039 non-null   float64
#  2   High       6039 non-null   float64
#  3   Low        6039 non-null   float64
#  4   Close      6039 non-null   float64
#  5   Adj Close  6039 non-null   float64
#  6   Volume     6039 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 330.4+ KB

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           6039  6039.000000  6039.000000  6039.000000
# mean   2011-01-02 18:48:49.359165440    33.032739    33.424013    32.598322
# min              1999-01-04 00:00:00     0.295500     0.305000     0.275500
# 25%              2005-01-04 12:00:00     2.267000     2.303500     2.226000
# 50%              2011-01-03 00:00:00     8.675000     8.758500     8.576500
# 75%              2017-01-01 00:00:00    41.047501    41.131498    40.737999
# max              2022-12-30 00:00:00   187.199997   188.654007   184.839493
# std                              NaN    48.808735    49.374865    48.170554
#
#              Close    Adj Close        Volume
# count  6039.000000  6039.000000  6.039000e+03
# mean     33.016059    33.016059  1.334297e+08
# min       0.298500     0.298500  1.762600e+07
# 25%       2.264250     2.264250  6.955200e+07
# 50%       8.685500     8.685500  1.054160e+08
# ...

# %%
df.nunique()
# Out:
# Date         6039
# Open         5404
# High         5368
# Low          5377
# Close        5491
# Adj Close    5491
# Volume       5872
# dtype: int64

# %%
df.isnull()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 6034  False  False  False  False  False      False   False
# 6035  False  False  False  False  False      False   False
# 6036  False  False  False  False  False      False   False
# 6037  False  False  False  False  False      False   False
# 6038  False  False  False  False  False      False   False
#
# [6039 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6034    False
# 6035    False
# 6036    False
# 6037    False
# 6038    False
# Length: 6039, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# # **Visualizing The Outliers**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(df ['Date'], period=12, model='add')

# Extract components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the components
plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(df['High'], label='Original')
plt.legend()

plt.subplot(412)
plt.plot(trend, label='Trend', color='red')
plt.legend()

plt.subplot(413)
plt.plot(seasonal, label='Seasonal', color='green')
plt.legend()

plt.subplot(414)
plt.plot(residual, label='Residual', color='purple')
plt.legend()

plt.tight_layout()
plt.show()

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns.tolist()

# Create boxplots for each numerical column
plt.figure(figsize=(12, 8))
for i, col in enumerate(numerical_columns):
    plt.subplot(3, 3, i + 1)  # Adjust subplot layout based on the number of numerical columns
    sns.boxplot(x=df[col], color='skyblue')
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.grid(True)

plt.tight_layout()  # Adjust subplot layout for better spacing
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
numerical_columns = df.select_dtypes(include=['number']).columns.tolist()

for column in numerical_columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)

num_plots = len(numerical_columns)
fig, axes = plt.subplots(nrows=num_plots, ncols=1, figsize=(8, 6 * num_plots))

for i, column in enumerate(numerical_columns):
    sns.boxplot(x=df[column], ax=axes[i], color="skyblue")
    axes[i].set_title(f'Boxplot for {column}')


plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %% [markdown]
# # **Data Visualization**

# %%
df.set_index('Date', inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label='Closing Price')
plt.title('Amazon Stock Closing Price (1999-2022)')
plt.xlabel('Date')
plt.ylabel('Closing Price ($)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(df['Open'],label='Opening Price')

plt.title('Time Series of Amazon Stock Opening Prices (1999-2022)')
plt.xlabel('Date')
plt.ylabel('Opening Price')
plt.grid(True)
plt.legend()


plt.show()

# %%
plt.plot(df.index, df['High'], color='skyblue', linewidth=1.5)

plt.title('Daily High Prices of Amazon Stock (1999-2022)')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.grid(True)

plt.show()

# %%
df = pd.read_csv('Amazon stock 1999 to 2022.csv')

df['Date'] = pd.to_datetime(df['Date'])


df['Year'] = df['Date'].dt.year

unique_years = df['Year'].unique()

for year in unique_years:
    year_data = df[df['Year'] == year]

    plt.figure(figsize=(10, 6))
    plt.plot(year_data['Date'], year_data['High'], color='skyblue', linewidth=1.5)

    plt.title(f'Daily High Prices of Amazon Stock - {year}')
    plt.xlabel('Date')
    plt.ylabel('High Price')
    plt.grid(True)

    plt.show()

# %%
# Histogram of Closing Prices
plt.figure(figsize=(10, 6))
plt.hist(df['Close'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Amazon Stock Closing Prices')
plt.xlabel('Closing Price ($)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Plotting Volume traded over time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Volume'], label='Volume')
plt.title('Volume Traded of Amazon Stock (1999-2022)')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# XX

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.arima_model import ARIMA
import numpy as np

def check_stationarity(timeseries):
    adf_test = adfuller(timeseries)
    critical_values = adf_test[4]

    print(f"ADF Statistic: {adf_test[0]:.4f}")
    print(f"p-value: {adf_test[1]:.4f}")
    print(f"Critical Values:")
    for key, value in critical_values.items():
        print(f"{key} ({value:.4f})")

    is_stationary = adf_test[1] < 0.05
    return is_stationary

def plot_acf_pacf(timeseries):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

    acf_values = acf(timeseries)
    pacf_values = pacf(timeseries)

    lags = np.arange(len(acf_values))

    ax1.bar(lags, acf_values, color='skyblue', alpha=0.7)
    ax1.axhline(y=0, color='r', linestyle='--', alpha=0.7)
    ax1.axhline(y=1.96/np.sqrt(len(timeseries)), color='gray', linestyle='--', alpha=0.7)
    ax1.axhline(y=-1.96/np.sqrt(len(timeseries)), color='gray', linestyle='--', alpha=0.7)
    ax1.set_title('Autocorrelation Function')
    ax1.set_xlabel('Lags')  #
    ax1.set_ylabel('ACF')
    ax1.set_xticks(lags)

    ax2.bar(lags, pacf_values, color='skyblue', alpha=0.7)
    ax2.axhline(y=0, color='r', linestyle='--', alpha=0.7)
    ax2.axhline(y=1.96/np.sqrt(len(timeseries)), color='gray', linestyle='--', alpha=0.7)
    ax2.axhline(y=-1.96/np.sqrt(len(timeseries)), color='gray', linestyle='--', alpha=0.7)
    ax2.set_title('Partial Autocorrelation Function')
    ax2.set_xlabel('Lags')
    ax2.set_ylabel('PACF')
    ax2.set_xticks(lags)
    plt.tight_layout()
    plt.show()

df = pd.read_csv('Amazon stock 1999 to 2022.csv')

df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

timeseries_data = df['High']

print("Checking stationarity of the original time series:")
is_stationary = check_stationarity(timeseries_data)

if not is_stationary:
    differenced_data = timeseries_data.diff().dropna()

    print("\nChecking stationarity of the differenced time series:")
    is_stationary_after_diff = check_stationarity(differenced_data)

    print("\nPlotting ACF and PACF of the differenced time series:")
    plot_acf_pacf(differenced_data)

    if is_stationary_after_diff:
        print("\nThe differenced series is now stationary.")
    else:
        print("\nFurther preprocessing may be needed to achieve stationarity.")

else:
    print("\nThe original time series is stationary.")
# Out:
# Checking stationarity of the original time series:
# ADF Statistic: -0.6723
# p-value: 0.8538
# Critical Values:
# 1% (-3.4314)
# 5% (-2.8620)
# 10% (-2.5670)
#
# Checking stationarity of the differenced time series:
# ADF Statistic: -13.8114
# p-value: 0.0000
# Critical Values:
# 1% (-3.4314)
# 5% (-2.8620)
# 10% (-2.5670)
#
# Plotting ACF and PACF of the differenced time series:
# The differenced series is now stationary.

# %%
train_data = df['High'][:len(df) // 2]
test_data = df['High'][len(df) // 2:]

# %%
p, d, q = 4, 2, 1

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train_data, order=(p, d, q))
fitted_model = model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
start_idx = len(train_data)
end_idx = len(df) - 1
predictions = fitted_model.predict(start=start_idx, end=end_idx, typ='levels')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
predictions = fitted_model.predict(start=len(train_data), end=len(df) - 1)
predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 3019     9.113217
# 3020     9.125831
# 3021     9.129636
# 3022     9.136260
# 3023     9.142368
#           ...
# 6034    26.045773
# 6035    26.051387
# 6036    26.057001
# 6037    26.062615
# 6038    26.068229
# Name: predicted_mean, Length: 3020, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calculate evaluation metrics
mse = mean_squared_error(test_data, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data, predictions)

absolute_errors = np.abs(test_data - predictions)
percentage_errors = absolute_errors / test_data.replace(0, np.nan)
percentage_errors = percentage_errors.fillna(0)
mape = np.mean(percentage_errors) * 100

print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Root Mean Squared Error (RMSE): 68.48
# Mean Squared Error (MSE): 4689.74
# Mean Absolute Error (MAE): 46.53
# Mean Absolute Percentage Error (MAPE): 0.00%
# <ipython-input-34-dc43c6d7df2f>:9: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects.
#   percentage_errors = absolute_errors / test_data.replace(0, np.nan)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['High'], label='Actual High Prices', color='blue')
plt.plot(test_data.index, predictions, label='Predicted High Prices', color='red')
plt.title('ARIMA Model Forecasting')
plt.xlabel('Date')
plt.ylabel('High Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
future_predictions = fitted_model.predict(start=len(df), end=len(df) + 100)
future_predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 6039    26.073843
# 6040    26.079457
# 6041    26.085071
# 6042    26.090685
# 6043    26.096299
#           ...
# 6135    26.612782
# 6136    26.618396
# 6137    26.624010
# 6138    26.629623
# 6139    26.635237
# Name: predicted_mean, Length: 101, dtype: float64

# %%
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
order = (2, 1, 2)
seasonal_order = (0, 1, 1, 12)

# %%
model = SARIMAX(df['High'], order=order, seasonal_order=seasonal_order)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit()

# %%
print(model_fit.summary())
# Out:
#                                       SARIMAX Results
# ...
# Dep. Variable:                                 High   No. Observations:                 6039
# Model:             SARIMAX(2, 1, 2)x(0, 1, [1], 12)   Log Likelihood               -9318.231
# Date:                              Mon, 22 Apr 2024   AIC                          18648.461
# Time:                                      16:12:02   BIC                          18688.684
# Sample:                                           0   HQIC                         18662.426
#                                              - 6039
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1249      0.064     -1.946      0.052      -0.251       0.001
# ar.L2         -0.4745      0.032    -14.707      0.000      -0.538      -0.411
# ...

# %%
size = int(len(df) - 30)
train = df['High'][:size]
test = df['High'][size:]

print('\t SARIMA MODEL : In - Sample Forecasting \n')
history = [x for x in train]
predictions = []
# Out:
# 	 SARIMA MODEL : In - Sample Forecasting

# %%
max_forecast_steps = 100

for t in range(min(len(test), max_forecast_steps)):
    model = SARIMAX(history, order=(2, 1, 2), seasonal_order=(0, 1, 1, 12))
    model_fit = model.fit()

    output = model_fit.forecast()
    yhat = output[0]

    predictions.append(float(yhat))

    obs = test[t]
    history.append(obs)

    print(f'Predicted = {yhat:.2f}, Expected = {obs:.2f}')

predictions_series = pd.Series(predictions, index=test.index[:len(predictions)])
# Out:
# <ipython-input-43-53435631134c>:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obs = test[t]
# Predicted = 98.35, Expected = 96.97
# Predicted = 96.42, Expected = 95.99
# Predicted = 96.61, Expected = 95.02
# Predicted = 95.09, Expected = 93.35
# Predicted = 93.08, Expected = 94.58
# Predicted = 94.46, Expected = 94.43
# Predicted = 94.95, Expected = 96.40
# Predicted = 96.29, Expected = 94.41
# Predicted = 94.11, Expected = 96.54
# Predicted = 96.47, Expected = 97.23
# Predicted = 97.07, Expected = 95.36
# Predicted = 95.25, Expected = 94.06
# Predicted = 93.95, Expected = 91.04
# Predicted = 90.78, Expected = 89.89
# Predicted = 90.32, Expected = 90.86
# Predicted = 91.02, Expected = 90.30
# Predicted = 90.26, Expected = 90.58
# Predicted = 90.26, Expected = 96.25
# ...

# %%
# Plotting the predicted values
plt.figure(figsize=(15, 5))
plt.plot(test.index[:len(predictions)], predictions_series, label='Predicted Values', color='red')
plt.plot(test, label='Expected Values', color='blue')
plt.title('SARIMA Model Forecasting for Amazon Stock Prices')
plt.xlabel('Date')
plt.ylabel('High Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
closing_prices = df['Close']

test_size = 30
train_prices = closing_prices[:-test_size]
test_prices = closing_prices[-test_size:]

order = (2, 1, 2)           # Non-seasonal (p, d, q)
seasonal_order = (0, 1, 1, 12)  # Seasonal (P, D, Q, S)

model = SARIMAX(train_prices, order=order, seasonal_order=seasonal_order)

model_fit = model.fit()

forecast_steps = len(test_prices)
forecast = model_fit.forecast(steps=forecast_steps)

rmse = np.sqrt(mean_squared_error(test_prices, forecast))
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

plt.figure(figsize=(14, 8))

# Plotting the train data
plt.plot(train_prices.index, train_prices, label='Train Data', color='blue')

# Plotting the test data (actual closing prices)
plt.plot(test_prices.index, test_prices, label='Test Data', color='green')

# Plotting the forecasted closing prices
plt.plot(test_prices.index, forecast, label='Forecasted Prices', color='red')

plt.title('SARIMA Forecasting for Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Prices')
plt.legend()

plt.grid(True)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
# ...

# %%
# Get the differenced series (first difference)
diff_series = closing_prices.diff(periods=1)

# Integrated (differenced) series represents the trend component
trend_component = diff_series.cumsum()

# Plot the trend component
plt.figure(figsize=(12, 6))
plt.plot(closing_prices.index, closing_prices, label='Original Data', color='blue', alpha=0.5)
plt.plot(trend_component.index, trend_component, label='Trend Component', color='red')
plt.title('Trend Component of Closing Prices (SARIMA)')
plt.xlabel('Date')
plt.ylabel('Closing Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Convert index to DatetimeIndex
df.index = pd.to_datetime(df.index)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
